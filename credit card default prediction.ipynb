# %% [markdown]
# # Credit Card Fraud Detection (Data Visualization using Seaborn)

# %% [markdown]
# # Step 1: Features of Dataset

# %% [markdown]
# 1. ID: ID of each client
# 2. LIMIT_BAL: Amount of given credit in NT dollars (includes individual and family/supplementary credit
# 3. SEX: Gender (1=male, 2=female)
# 4. EDUCATION: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)
# 5. MARRIAGE: Marital status (1=married, 2=single, 3=others)
# 6. AGE: Age in years
# 7. PAY_0: Repayment status in September, 2005 (-1=pay duly, 1=payment delay for one month, 2=payment delay for two months,8=payment delay for eight months, 9=payment delay for nine months and above)
# 8. PAY_2: Repayment status in August, 2005 (scale same as above)
# 9. PAY_3: Repayment status in July, 2005 (scale same as above)
# 10. PAY_4: Repayment status in June, 2005 (scale same as above)
# 11. PAY_5: Repayment status in May, 2005 (scale same as above)
# 12. PAY_6: Repayment status in April, 2005 (scale same as above)
# 13. BILL_AMT1: Amount of bill statement in September, 2005 (NT dollar)
# 14. BILL_AMT2: Amount of bill statement in August, 2005 (NT dollar)
# 15. BILL_AMT3: Amount of bill statement in July, 2005 (NT dollar)
# 16. BILL_AMT4: Amount of bill statement in June, 2005 (NT dollar)
# 17. BILL_AMT5: Amount of bill statement in May, 2005 (NT dollar)
# 18. BILL_AMT6: Amount of bill statement in April, 2005 (NT dollar)
# 19. PAY_AMT1: Amount of previous payment in September, 2005 (NT dollar)
# 20. PAY_AMT2: Amount of previous payment in August, 2005 (NT dollar)
# 21. PAY_AMT3: Amount of previous payment in July, 2005 (NT dollar)
# 22. PAY_AMT4: Amount of previous payment in June, 2005 (NT dollar)
# 22. PAY_AMT5: Amount of previous payment in May, 2005 (NT dollar)
# 23. PAY_AMT6: Amount of previous payment in April, 2005 (NT dollar)
# 24. default.payment.next.month: Default payment (1=yes, 0=no)

# %% [markdown]
# #  Step 2: Import all necessary Libraries

# %% [markdown]
# 1. Pandas : Pandas is a open source library which is use for data analysis.
# 2. Numpy :  NumPy is a python library used for working with arrays
# 3. Seaborn : Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing              attractive and informative statistical graphics.Seaborn helps you explore and understand your data.
# 4. Matplotlib : Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Step 3: Import the Dataset

# %%
df=pd.read_excel("default_of_credit_card_clients.xls")
#df = df.sample(n=2000,replace =False,random_state=1)
df.shape
# Out:
# (30000, 25)

# %%
df.head(5)
# Out:
#                   ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE          PAY_1  \
# 10747  d3d27444-3202     310000    1          3         1   32              0
# 12573  d897e94b-18b3      10000    2          3         1   49             -1
# 29676  5ea2400b-c2e7      50000    1          2         1   28             -1
# 8856   5eab1537-c3de      80000    2          3         1   52              2
# 21098  c2f2ccfb-40d3     270000    1          1         2   34  Not available
#
#        PAY_2  PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  \
# 10747      0      0      0  ...      84373      57779      14163      8295
# 12573     -1     -2     -1  ...       1690       1138        930         0
# 29676     -1     -1      0  ...      45975       1300      43987         0
# 8856       2      3      3  ...      40748      39816      40607      3700
# 21098      2      0      0  ...      22448      15490      17343         0
#
# ...

# %%
df.tail(5)
# Out:
#                   ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 23295  db9bc125-f0ea     160000    2          1         2   25    -1      0
# 15148  b0feaa0e-455e     250000    1          1         1   53    -2     -2
# 18666  07480fcf-b8fd      50000    2          1         2   23    -1     -1
# 3415   d2d6d08c-705f     200000    2          2         1   37     0      0
# 18714  8f1a484b-b07d     420000    2          1         2   28     0      0
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 23295     -1     -1  ...       2199      10856          0      1000     11426
# 15148     -2     -2  ...          0          0          0         0         0
# 18666     -2     -2  ...          0          0          0         0         0
# 3415       0      0  ...     191730     171269     151550      8017      8000
# 18714     -1      0  ...      65592      57438      31029      1010     64513
#
# ...

# %% [markdown]
# # Step 4: Apply some Feature Engineering

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 10747 to 18714
# Data columns (total 25 columns):
# ID                            2000 non-null object
# LIMIT_BAL                     2000 non-null int64
# SEX                           2000 non-null int64
# EDUCATION                     2000 non-null int64
# MARRIAGE                      2000 non-null int64
# AGE                           2000 non-null int64
# PAY_1                         2000 non-null object
# PAY_2                         2000 non-null int64
# PAY_3                         2000 non-null int64
# PAY_4                         2000 non-null int64
# PAY_5                         2000 non-null int64
# PAY_6                         2000 non-null int64
# BILL_AMT1                     2000 non-null int64
# BILL_AMT2                     2000 non-null int64
# BILL_AMT3                     2000 non-null int64
# BILL_AMT4                     2000 non-null int64
# ...

# %%
df.describe()
# Out:
#            LIMIT_BAL          SEX    EDUCATION     MARRIAGE          AGE  \
# count    2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean   169460.000000     1.583000     1.831500     1.537500    35.034500
# std    131907.953718     0.516957     0.818806     0.541055     9.887325
# min         0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     50000.000000     1.000000     1.000000     1.000000    28.000000
# 50%    140000.000000     2.000000     2.000000     2.000000    34.000000
# 75%    250000.000000     2.000000     2.000000     2.000000    41.000000
# max    730000.000000     2.000000     6.000000     3.000000    71.000000
#
#              PAY_2        PAY_3        PAY_4        PAY_5        PAY_6  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean     -0.135000    -0.174500    -0.207500    -0.243500    -0.265000  ...
# std       1.150407     1.167789     1.154604     1.124651     1.159503  ...
# ...

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df.drop(['ID'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
df.head()
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE          PAY_1  PAY_2  PAY_3  \
# 10747     310000    1          3         1   32              0      0      0
# 12573      10000    2          3         1   49             -1     -1     -2
# 29676      50000    1          2         1   28             -1     -1     -1
# 8856       80000    2          3         1   52              2      2      3
# 21098     270000    1          1         2   34  Not available      2      0
#
#        PAY_4  PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 10747      0      0  ...      84373      57779      14163      8295      6000
# 12573     -1      2  ...       1690       1138        930         0         0
# 29676      0     -1  ...      45975       1300      43987         0     46257
# 8856       3      3  ...      40748      39816      40607      3700      1600
# 21098      0      2  ...      22448      15490      17343         0      4000
#
# ...

# %%
# This function is use for checking null values
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_1                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
df['SEX'].value_counts(dropna=False)
# Out:
# 2    1190
# 1     786
# 0      24
# Name: SEX, dtype: int64

# %% [markdown]
# # Step 5 : Data Visualization

# %% [markdown]
# 1. Countplot : A countplot is kind of likea histogram or a bar graph for some categorical area. It simply shows the number of occurrences of an item based on a certain type of category.

# %%
sns.countplot("SEX",data=df)

# %%
sns.countplot("EDUCATION",data=df,color="pink")

# %%
plt.figure(figsize=(15,8))
sns.countplot("AGE",data=df,color="cyan")

# %%
plt.figure(figsize=(10,8))
sns.countplot('MARRIAGE',data=df)

# %%
plt.figure(figsize=(6,8))
sns.countplot("default payment next month",data=df)

# %%
plt.figure(figsize=(10,8))
sns.countplot(x="SEX",hue="default payment next month",data=df)

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='MARRIAGE',hue="default payment next month",data=df)

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='EDUCATION',hue="default payment next month",data=df)

# %% [markdown]
# 2. Barplot : Bar graphs are useful for displaying relationships between categorical data and at least one numerical variable

# %%
plt.figure(figsize=(8,8))
sns.barplot(x="SEX",y="LIMIT_BAL",data=df)

# %% [markdown]
# 3. Boxplot: The seaborn boxplot is a very basic plot Boxplots are used to visualize distributions. Thats very useful when you want to compare data between two groups

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='default payment next month',y='AGE',data=df,palette='rainbow')

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='default payment next month',hue='MARRIAGE',y='AGE',data=df,palette='rainbow')

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='default payment next month',hue='EDUCATION',y='AGE',data=df,palette='rainbow')

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='EDUCATION',hue='default payment next month', y='LIMIT_BAL',data=df,palette="rainbow")

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x='MARRIAGE',hue='default payment next month', y='LIMIT_BAL',data=df,palette="rainbow")

# %% [markdown]
# 4. Distplot : A Distplot or distribution plot, depicts the variation in the data distribution. Seaborn Distplot represents the overall distribution of continuous data variables.

# %%
sns.distplot(df['LIMIT_BAL'],kde=True,bins=30)

# %% [markdown]
# 5. Pairplot : A pairplot plot a pairwise relationships in a dataset. The pairplot function creates a grid of Axes such that each variable in data will by shared in the y-axis across a single row and in the x-axis across a single column

# %%
# plot columns with similar names to check the correlation
sns.pairplot(df, vars=df.columns[11:17], kind='scatter',hue= 'default payment next month')
sns.pairplot(df, vars=df.columns[17:23],hue = 'default payment next month')

# %% [markdown]
# # Correlation

# %% [markdown]
# 6. heatmap : A heatmap is a graphical representation where individual values of a matrix are represented as colors. A heatmap is very useful in visualizing the concentration of values between two dimensions of a matrix.

# %%
plt.subplots(figsize=(30,20))
sns.heatmap(df.corr(),annot=True,fmt=".3f" )

# %% [markdown]
# 7. jointplot : Jointplot is seaborn library specific and can be used to quickly visualize and analyze the relationship between two variables and describe their individual distributions on the same plot. .

# %%
sns.jointplot(x='LIMIT_BAL',y='AGE',data=df,kind="scatter")
